# %% [markdown]
# <a href="https://colab.research.google.com/github/raisharad/GenerativeAIandAgenticAI/blob/main/May23Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as stats
n,r,p = 8,3,0.6
stats.binom.pmf(r,n,p)
# Out:
# np.float64(0.12386304000000004)

# %%
import scipy.stats as stats
n,r,p = 8,4,0.6
stats.binom.cdf(r,n,p)
# Out:
# np.float64(0.40591360000000004)

# %%
import scipy.stats as stats
lam =2
r=3
stats.poisson.pmf(r,lam)
# Out:
# np.float64(0.18044704431548356)

# %%
import scipy.stats as stats
lam =2
r=2
stats.poisson.cdf(r,lam)
# Out:
# np.float64(0.6766764161830634)

# %%
income_score = 80
credit_score= 90
repayment_score =70
weight= [0.4,0.4,0.2]

final_score=(
             income_score*weight[0]+
             credit_score*weight[1]+
             repayment_score*weight[2]
)

print("final AI ", final_score)
# Out:
# final AI  82.0
