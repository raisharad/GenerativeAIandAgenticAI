# %% [markdown]
# <a href="https://colab.research.google.com/github/raisharad/GenerativeAIandAgenticAI/blob/main/June13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Deep Learning Hands-On: CNN & RNN from Scratch
# What we will cover
# How images are stored as numbers (B&W → Grayscale → Colour)
# What CNN filters do
# Building and training a CNN on image classification
# Why CNN struggles with text
# Word embeddings and RNNs for text classification
# How to use this notebook
# Pre-filled cells — read, run, observe the output
# ✏️ DIY cells — you write the code (hints are provided!)
# Run cells in order, top to bottom

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

print("✅ All imports successful!")
print(f"   PyTorch version : {torch.__version__}")
print(f"   GPU available   : {torch.cuda.is_available()}")
