# %% [markdown]
# <a href="https://colab.research.google.com/github/raisharad/GenerativeAIandAgenticAI/blob/main/May23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
product=3

while product<=50 :
   product = product*3
   print(product)

product
# Out:
# 9
# 27
# 81
# 81

# %%
product=7

while product < 1000 :
   product = product*7
   print(product)

product
# Out:
# 49
# 343
# 2401
# 2401

# %%
for charecter in "programming" :
  print(charecter, end=' ')
# Out:
# p r o g r a m m i n g

# %%
total=0

for number in [4,5,-8,9,11] :
   total =total + number

total
# Out:
# 21

# %%
import numpy as np
a=np.array([1,2,3])
a
a.dtype
# Out:
# dtype('int64')

# %%
a.shape
# Out:
# (3,)

# %%
a.size
# Out:
# 3

# %%
b=np.array([[1,2],[3,4]])
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b=np.array([(1,2),[3,4],(3,4)])
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [3, 4]])
